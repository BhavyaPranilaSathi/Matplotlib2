# %%
#Scatter Plot
import matplotlib.pyplot as plt
 
x =[5, 7, 8, 7, 2, 17, 2, 9,
    4, 11, 12, 9, 6] 
 
y =[99, 86, 87, 88, 100, 86, 
    103, 87, 94, 78, 77, 85, 86]
 
plt.scatter(x, y, c ="black")
 
plt.show()

# %%
# Plot Multiple Datasets on a Scatterplot
#1st
x1 = [89, 43, 36, 36, 95, 10, 66, 34, 38, 20]
y1 = [21, 46, 3, 35, 67, 95, 53, 72, 58, 10]

# 2nd
x2 = [26, 29, 48, 64, 6, 5, 36, 66, 72, 40]

y2 = [26, 34, 90, 33, 38, 20, 56, 2, 47, 15]

#plots
plt.scatter(x1, y1, c ="pink", linewidths = 2, marker ="s", edgecolor ="green", s = 50)
plt.scatter(x2, y2, c ="yellow",linewidths = 2,marker ="^", edgecolor ="red", s = 200)

# Title and Labels
plt.title('Multiple Scatterplots')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Display the plot
plt.show()

# %%
#Scatter plot with bubbles 
import matplotlib.pyplot as plt
 
# Data
x_values = [1, 2, 3, 4, 5]
y_values = [2, 3, 5, 7, 11]
bubble_sizes = [30, 80, 150, 200, 300]
 
# Create bubble chart 
plt.scatter(x_values, y_values, s=bubble_sizes, alpha=0.6, c = 'green', edgecolors='blue', linewidths=2)
 
#title and labels
plt.title("Bubble Chart")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
 

plt.show()

# %%
#Scatter plot with color bar

import matplotlib.pyplot as plt
import numpy as np
 
# random data
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 100 * np.random.rand(50)
 
#customized scatter plot
plt.scatter(x, y, c=colors, s=sizes, alpha=0.7, cmap='viridis')
 
# title and labels
plt.title("Customized Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
 
# color scale
plt.colorbar(label='Color Scale')
plt.show()
